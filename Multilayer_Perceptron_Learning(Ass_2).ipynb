# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshyasanskruti/Deep-Learning/blob/main/Multilayer_Perceptron_Learning(Ass_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SAMIKSHYA SANSKRUTI SWAIN**

# %% [markdown]
# **1.Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils  import to_categorical

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **2.Dataset Analysis**

# %%
# Load Dataset

url='https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'
data=pd.read_csv(url,delimiter=';')

# %%
print("Dataset Sample:")
data.head()
# Out:
# Dataset Sample:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
data.describe().T
# Out:
#                        count        mean        std      min         25%  \
# fixed acidity         4898.0    6.854788   0.843868  3.80000    6.300000
# volatile acidity      4898.0    0.278241   0.100795  0.08000    0.210000
# citric acid           4898.0    0.334192   0.121020  0.00000    0.270000
# residual sugar        4898.0    6.391415   5.072058  0.60000    1.700000
# chlorides             4898.0    0.045772   0.021848  0.00900    0.036000
# free sulfur dioxide   4898.0   35.308085  17.007137  2.00000   23.000000
# total sulfur dioxide  4898.0  138.360657  42.498065  9.00000  108.000000
# density               4898.0    0.994027   0.002991  0.98711    0.991723
# pH                    4898.0    3.188267   0.151001  2.72000    3.090000
# sulphates             4898.0    0.489847   0.114126  0.22000    0.410000
# alcohol               4898.0   10.514267   1.230621  8.00000    9.500000
# quality               4898.0    5.877909   0.885639  3.00000    5.000000
#
#                             50%       75%        max
# fixed acidity           6.80000    7.3000   14.20000
# volatile acidity        0.26000    0.3200    1.10000
# citric acid             0.32000    0.3900    1.66000
# residual sugar          5.20000    9.9000   65.80000
# chlorides               0.04300    0.0500    0.34600
# free sulfur dioxide    34.00000   46.0000  289.00000
# total sulfur dioxide  134.00000  167.0000  440.00000
# density                 0.99374    0.9961    1.03898
# pH                      3.18000    3.2800    3.82000
# sulphates               0.47000    0.5500    1.08000
# alcohol                10.40000   11.4000   14.20000
# quality                 6.00000    6.0000    9.00000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
#  **3.Preprocessing**

# %%
#split into features and target
X=data.drop('quality',axis=1)
y_categorical=to_categorical(data['quality'])

# split training (80%) and testing(20%) sets
X_train,X_test,y_train,y_test=train_test_split(X,y_categorical,test_size=0.2,random_state=42)

print("\nTraining Set Size :", X_train.shape)
print("Testing Set Size :",X_test.shape)
# Out:
# Training Set Size : (3918, 11)
# Testing Set Size : (980, 11)

# %%
#standardize the feature using standardscaler

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
print("\nFeature Standardization Completed")
# Out:
# Feature Standardization Completed

# %% [markdown]
# **4.Perform Explaratory Data Analysis (EDA)**

# %%
#plot class distribution
sns.countplot(x=data['quality'])
plt.title(" Distribution of wine quality")
plt.show()

#correlation heatmap
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm',fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# **5.Build and Train an MLP Classifier**

# %%
#create the MLP model

model=keras.Sequential([
    keras.layers.Dense(64,activation='relu',input_shape=(X_train.shape[1],)),
    keras.layers.Dense(32,activation='relu'),
    keras.layers.Dense(16,activation='relu'),
    keras.layers.Dense(y_categorical.shape[1],activation='softmax') # Changed to y_categorical.shape[1] neurons and softmax activation
])


model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │           170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,546 (13.85 KB)
#  Trainable params: 3,546 (13.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compile model
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])


#Train model
history=model.fit(X_train,y_train,epochs=50,validation_data=(X_test,y_test),verbose=1)
# Out:
# Epoch 1/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3325 - loss: 1.8926 - val_accuracy: 0.5112 - val_loss: 1.2237
# Epoch 2/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5245 - loss: 1.1854 - val_accuracy: 0.5296 - val_loss: 1.1448
# Epoch 3/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5369 - loss: 1.1123 - val_accuracy: 0.5418 - val_loss: 1.1204
# Epoch 4/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5623 - loss: 1.0797 - val_accuracy: 0.5235 - val_loss: 1.1059
# Epoch 5/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5651 - loss: 1.0456 - val_accuracy: 0.5459 - val_loss: 1.0933
# Epoch 6/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5684 - loss: 1.0430 - val_accuracy: 0.5429 - val_loss: 1.0848
# Epoch 7/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5664 - loss: 1.0414 - val_accuracy: 0.5327 - val_loss: 1.0776
# Epoch 8/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5773 - loss: 1.0209 - val_accuracy: 0.5551 - val_loss: 1.0662
# Epoch 9/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5665 - loss: 1.0332 - val_accuracy: 0.5643 - val_loss: 1.0631
# Epoch 10/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5788 - loss: 0.9942 - val_accuracy: 0.5520 - val_loss: 1.0538
# Epoch 11/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5961 - loss: 0.9842 - val_accuracy: 0.5551 - val_loss: 1.0534
# Epoch 12/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5959 - loss: 0.9857 - val_accuracy: 0.5735 - val_loss: 1.0478
# Epoch 13/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5883 - loss: 0.9763 - val_accuracy: 0.5541 - val_loss: 1.0469
# Epoch 14/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5981 - loss: 0.9604 - val_accuracy: 0.5653 - val_loss: 1.0353
# Epoch 15/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6020 - loss: 0.9452 - val_accuracy: 0.5469 - val_loss: 1.0601
# Epoch 16/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5885 - loss: 0.9623 - val_accuracy: 0.5684 - val_loss: 1.0308
# Epoch 17/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5901 - loss: 0.9587 - val_accuracy: 0.5755 - val_loss: 1.0376
# Epoch 18/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6049 - loss: 0.9420 - val_accuracy: 0.5724 - val_loss: 1.0333
# Epoch 19/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6004 - loss: 0.9148 - val_accuracy: 0.5653 - val_loss: 1.0278
# Epoch 20/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5995 - loss: 0.9218 - val_accuracy: 0.5755 - val_loss: 1.0383
# Epoch 21/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6161 - loss: 0.9172 - val_accuracy: 0.5694 - val_loss: 1.0265
# Epoch 22/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6098 - loss: 0.9110 - val_accuracy: 0.5714 - val_loss: 1.0348
# Epoch 23/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5964 - loss: 0.9202 - val_accuracy: 0.5837 - val_loss: 1.0267
# Epoch 24/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6101 - loss: 0.8963 - val_accuracy: 0.5714 - val_loss: 1.0279
# Epoch 25/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6257 - loss: 0.9014 - val_accuracy: 0.5755 - val_loss: 1.0330
# Epoch 26/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6011 - loss: 0.9212 - val_accuracy: 0.5714 - val_loss: 1.0220
# Epoch 27/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6267 - loss: 0.8844 - val_accuracy: 0.5796 - val_loss: 1.0210
# Epoch 28/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6312 - loss: 0.8746 - val_accuracy: 0.5755 - val_loss: 1.0264
# Epoch 29/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6260 - loss: 0.8956 - val_accuracy: 0.5765 - val_loss: 1.0247
# Epoch 30/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6307 - loss: 0.8750 - val_accuracy: 0.5929 - val_loss: 1.0290
# Epoch 31/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6234 - loss: 0.8861 - val_accuracy: 0.5857 - val_loss: 1.0226
# Epoch 32/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6363 - loss: 0.8768 - val_accuracy: 0.5724 - val_loss: 1.0350
# Epoch 33/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6427 - loss: 0.8551 - val_accuracy: 0.5765 - val_loss: 1.0306
# Epoch 34/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6425 - loss: 0.8713 - val_accuracy: 0.6000 - val_loss: 1.0299
# Epoch 35/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6601 - loss: 0.8310 - val_accuracy: 0.5765 - val_loss: 1.0301
# Epoch 36/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6258 - loss: 0.8803 - val_accuracy: 0.5806 - val_loss: 1.0421
# Epoch 37/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6351 - loss: 0.8551 - val_accuracy: 0.5786 - val_loss: 1.0546
# Epoch 38/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6439 - loss: 0.8320 - val_accuracy: 0.5878 - val_loss: 1.0438
# Epoch 39/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6482 - loss: 0.8557 - val_accuracy: 0.5735 - val_loss: 1.0389
# Epoch 40/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6521 - loss: 0.8406 - val_accuracy: 0.5908 - val_loss: 1.0396
# Epoch 41/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6535 - loss: 0.8150 - val_accuracy: 0.6000 - val_loss: 1.0403
# Epoch 42/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6558 - loss: 0.8138 - val_accuracy: 0.5867 - val_loss: 1.0414
# Epoch 43/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6644 - loss: 0.8168 - val_accuracy: 0.5776 - val_loss: 1.0482
# Epoch 44/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6548 - loss: 0.8272 - val_accuracy: 0.5980 - val_loss: 1.0540
# Epoch 45/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6682 - loss: 0.7881 - val_accuracy: 0.5918 - val_loss: 1.0433
# Epoch 46/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6790 - loss: 0.7884 - val_accuracy: 0.5929 - val_loss: 1.0523
# Epoch 47/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6715 - loss: 0.8230 - val_accuracy: 0.5837 - val_loss: 1.0635
# Epoch 48/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6667 - loss: 0.8033 - val_accuracy: 0.6112 - val_loss: 1.0547
# Epoch 49/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6708 - loss: 0.7961 - val_accuracy: 0.5857 - val_loss: 1.0648
# Epoch 50/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6664 - loss: 0.7943 - val_accuracy: 0.5755 - val_loss: 1.0814

# %% [markdown]
# **6.Evaluate Model Performance**

# %%
#prediction
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1) # Get predicted class index
y_true = np.argmax(y_test, axis=1) # Get true class index from one-hot encoded labels

#print performance matrics
print("Accuracy Score:",accuracy_score(y_true,y_pred))
print("Precision Score:",precision_score(y_true,y_pred,average='weighted'))
print("Recall Score:",recall_score(y_true,y_pred,average='weighted'))
print("F1 Score:",f1_score(y_true,y_pred,average='weighted'))

#Confusion Matrix
cm=confusion_matrix(y_true,y_pred)
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Confusion Matrix:")
plt.show()
print(cm)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Accuracy Score: 0.5755102040816327
# Precision Score: 0.5798363309534624
# Recall Score: 0.5755102040816327
# F1 Score: 0.5699914924430899
# [[  0   1   2   2   0   0]
#  [  1  10   9   3   2   0]
#  [  0   7 189  75  19   1]
#  [  0   0 102 236  94   0]
#  [  0   0   9  55 124   4]
#  [  0   0   1   8  21   5]]

# %% [markdown]
# **7.Plot Training Performance**

# %%
plt.figure(figsize=(16,4))

#plot loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'],label='Train Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.legend()
plt.title("Loss vs. Epochs")

#plot accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],label='Train Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.legend()
plt.title("Accuracy vs. Epochs")

plt.show()
