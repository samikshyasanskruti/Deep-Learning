# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshyasanskruti/Deep-Learning/blob/main/Object_Detection_%26_Segmentation_using_YOLOv8(Ass_6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SAMIKSHYA SANSKRUTI SWAIN**

# %% [markdown]
# **Install and Import Required Libraries**

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# **1.OBJECT DETECTION**

# %%
# Load the object detection model
model_detect = YOLO('yolov8n.pt')  # Use yolov8s.pt for better accuracy

# Run inference on an image
image_path ="https://cdn.pixabay.com/photo/2022/06/19/18/31/traffic-7272520_960_720.jpg"

# Replace with actual image path
results = model_detect(image_path)
results[0].save(filename='output_detection.jpg')

# Display result
img = cv2.imread('output_detection.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Object Detection")
plt.axis('off')
plt.show()
# Out:
# ...
# 100%|██████████| 315k/315k [00:00<00:00, 7.46MB/s]
# image 1/1 /content/traffic-7272520_960_720.jpg: 448x640 4 persons, 18 cars, 3 buss, 2 trucks, 39.6ms
# Speed: 2.4ms preprocess, 39.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# **2.INSTANCE SEGMENTATION**

# %%
# Load the segmentation model
model_seg = YOLO('yolov8n-seg.pt')  # Segmentation model

# Run segmentation
results_seg = model_seg(image_path)
results_seg[0].save(filename='output_segmentation.jpg')

# Display result
img_seg = cv2.imread('output_segmentation.jpg')
plt.imshow(cv2.cvtColor(img_seg, cv2.COLOR_BGR2RGB))
plt.title("Instance Segmentation")
plt.axis('off')
plt.show()
# Out:
# Found https://cdn.pixabay.com/photo/2022/06/19/18/31/traffic-7272520_960_720.jpg locally at traffic-7272520_960_720.jpg
# image 1/1 /content/traffic-7272520_960_720.jpg: 448x640 6 persons, 23 cars, 1 motorcycle, 3 buss, 1 truck, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 3.4ms postprocess per image at shape (1, 3, 448, 640)
